# %%
from Source.Anonymise import blurFace
from Source.Anonymise import detectFace
from Source.ImageView import singleView

lena = '../hdr-bilder/Faces/lena.png'
team = '../hdr-bilder/Faces/team.jpg'
group = '../hdr-bilder/faces/group.jpeg'

# %%
antall, image = detectFace(lena)
antall, blur = blurFace(lena)
print(antall, "ansikt er registrert")   #teller opp antall ansikt funnet og skriver de ut    
singleView(image, "Lena")            #displayer bildet
singleView(blur, "Anonymous Lena")
# Out:
# 1 ansikt er registrert

# %%
antall, image = detectFace(team, 1.25037, 3)
antall, blur = blurFace(team, 1.25037, 3)
print(antall, "ansikt er registrert")    #teller opp antall ansikt funnet og skriver de ut    
singleView(image, "Team")                #displayer bildet
singleView(blur, "Anonymous Team")
# Out:
# 8 ansikt er registrert
