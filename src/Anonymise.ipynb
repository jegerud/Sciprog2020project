# %%
from Source.Anonymise import blurFace
from Source.Anonymise import detectFace
from Source.ImageView import singleView
from Source.Anonymise import detect_anonymise

lena = '../hdr-bilder/Faces/lena.png'
group = '../hdr-bilder/faces/group1.jpg'
couple = '../hdr-bilder/Faces/couple.jpg'

# %%
detect_anonymise(lena)
# Out:
# 1 ansikt er registrert

# %%
detect_anonymise(group)
# Out:
# 7 ansikt er registrert

# %%
detect_anonymise(couple)
# Out:
# 2 ansikt er registrert
