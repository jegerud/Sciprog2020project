# %%
from Source.Anonymise import blurFace
from Source.ImageView import singleView

lena = '../hdr-bilder/Faces/lena.png'
LFC = '../hdr-bilder/Faces/team.jpg'
group = '../hdr-bilder/faces/group.jpeg'

# %%
antall, image = blurFace(lena)
print(antall, "ansikt er registrert")   #teller opp antall ansikt funnet og skriver de ut    
singleView(image, "Lena")            #displayer bildet
# Out:
# 1 ansikt er registrert

# %%
antall, image = blurFace(LFC)
print(antall, "ansikt er registrert")    #teller opp antall ansikt funnet og skriver de ut    
singleView(image, "LFC")              #displayer bildet
# Out:
# 7 ansikt er registrert

# %%
antall, image = anonym.blurFace(group)
print(antall, "ansikt er registrert")    #teller opp antall ansikt funnet og skriver de ut    
singleView(image, "Solbriller hindrer gjenkjenning")              #displayer bildet
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-38267fc47ef6> in <module>
# ----> 1 antall, image = anonym.blurFace(group)
#       2 print(antall, "ansikt er registrert")    #teller opp antall ansikt funnet og skriver de ut
#       3 singleView(image, "Solbriller hindrer gjenkjenning")              #displayer bildet
#
# NameError: name 'anonym' is not defined
