# %%
import Anonymise as anonym
import ImageView as iv

lena = '../hdr-bilder/Faces/lena.png'
LFC = '../hdr-bilder/Faces/team.jpg'
group = '../hdr-bilder/faces/group.jpeg'

# %%
antall, image = anonym.blurFace(lena)
print(antall, "ansikt er registrert")   #teller opp antall ansikt funnet og skriver de ut    
iv.singleView(image, "Lena")            #displayer bildet
# Out:
# 1 ansikt er registrert

# %%
antall, image = anonym.blurFace(LFC)
print(antall, "ansikt er registrert")    #teller opp antall ansikt funnet og skriver de ut    
iv.singleView(image, "LFC")              #displayer bildet
# Out:
# 7 ansikt er registrert

# %%
antall, image = anonym.blurFace(group)
print(antall, "ansikt er registrert")    #teller opp antall ansikt funnet og skriver de ut    
iv.singleView(image, "Solbriller hindrer gjenkjenning")              #displayer bildet
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-9f5bf4df8c03> in <module>
# ----> 1 antall, image = anonym.blurFace(group)
#       2 print(antall, "ansikt er registrert")    #teller opp antall ansikt funnet og skriver de ut
#       3 iv.singleView(image, "Solbriller hindrer gjenkjenning")              #displayer bildet
#
# ~/NTNU/Python/imt3881/imt3881-2020-prosjekt/src/Anonymise.py in blurFace(file, scaleFactor, minNeighbors)
#      20     """
#      21     image = cv2.imread(file) #leser inn bildet
# ---> 22     image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#      23
#      24     face_cascade = cv2.CascadeClassifier('Resources/haarcascade_frontalface_default.xml') #importerer haarscade biblioteket
#
# error: /build/opencv-L2vuMj/opencv-3.2.0+dfsg/modules/imgproc/src/color.cpp:9716: error: (-215) scn == 3 || scn == 4 in function cvtColor
