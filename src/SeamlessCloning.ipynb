# %%
from Source.SeamlessCloning import *
from Source.ImageView import *

# %%
im1='../hdr-bilder/Balls/Balls_00016.png' #from
im2='../hdr-bilder/Tree/Tree_00064.png'   #to

xy0 = (700,50)
xy1 = (350,500)
xlen = 200
ylen = 500

image = seamless(im1, im2, xy0, xy1, xlen, ylen)
singleView(image, True)

# %%
im1='../hdr-bilder/Seamless/bear.jpg' #from
im2='../hdr-bilder/Seamless/Abid.jpg'   #to

xy0 = (400,265)
xy1 = (0,0)    
xlen = 173      
ylen = 160      

#image = seamless(im1, im2, xy0, xy1, xlen, ylen)
#singleView(image, True)

# %%
im1='../hdr-bilder/Seamless/donald.jpg' #from
im2='../hdr-bilder/Seamless/baby.jpg'   #to

xy0 = (340,820)
xy1 = (240,590)    
xlen = 300      
ylen = 260      

image = seamless(im1, im2, xy0, xy1, xlen, ylen)
singleView(image, True)
