# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio
import sys
sys.path.insert(0, '../')
import Source.Eksplisitt  as eks
import Source.ImageView as imv
import Source.Grayscale as gray

# %%
def contrast(file, k):
    orig_im = imageio.imread(file).astype(float) / 255
    im = np.copy(orig_im)
    
    orig_gray_im = gray.rgb2gray(filepath)
    gray_im = gray.rgb2gray(filepath)
        
    im = eks.eksplisittKontrast(im, orig_im, k)
    gray_im = eks.eksplisittKontrast(gray_im, orig_gray_im, k)

    imv.view(orig_im, im, orig_gray_im, gray_im, "Kontrastforsterket") #Displayer bildene ved siden av hverandre

# %%
filepath = "../../hdr-bilder/Balls/Balls_00032.png"
constant = 2.5

contrast(filepath, constant)
