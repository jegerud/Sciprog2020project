# %%
import numpy as np
import imageio
import matplotlib.pyplot as plt
from Source.Grayscale import rgb2gray, grayscale
from Source.ImageView import singleView

file = '../hdr-bilder/Balls/Balls_00016.png' #leser inn bilder

# %%
image = rgb2gray(file)
im=grayscale(file)


plt.figure(figsize=(16, 8))         # Setter størrelse på bildene
plt.subplot(131)                    # Legger til subplot for bilde
plt.imshow(im, plt.cm.gray)   # Viser bildet
plt.title('enkel')          # Legger til tittel
plt.axis('off')                     # Fjerner aksene i figuren
    
plt.subplot(132)                    # Legger til subplot for bilde
plt.imshow(image, plt.cm.gray)        # Viser glattet bilde        
plt.title("avansert")                     # Legger til tittel
plt.axis('off')                     # Fjerner aksene i figuren
                                        # Gjør margene mindre
plt.subplots_adjust(wspace=0.02, hspace=0.02, top=0.9, bottom=0, left=0,right=1)
