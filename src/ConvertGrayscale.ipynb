# %%
import numpy as np
import imageio
import matplotlib.pyplot as plt
from Source.Grayscale import rgb2gray, grayscale, viewGrayImage

file = '../hdr-bilder/Balls/Balls_00016.png' #leser inn bilder

# %%
image = rgb2gray(file)
im=grayscale(file)
viewGrayImage(im,image)
